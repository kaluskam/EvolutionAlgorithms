# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

from cutting_stock_utils import *

# %%
os.chdir('..')

# %%
r800 = DataLoader().load('r800.csv')
r850 = DataLoader().load('r850.csv')
r1000 = DataLoader().load('r1000.csv')
r1100 = DataLoader().load('r1100.csv')
r1200 = DataLoader().load('r1200.csv')

# %% [markdown]
# # 1. Zbiór z promieniem 800

# %%
e800 = Evolution(crossover_ratio=0.7, mutation_ratio=0.2,
                     crossover=mean_crossover, mutation=int_mutation,
                     fitness_func=r800.fitness_function,
                     selection_func=elite_selection, population_size=60,
                     individual_size=r800.n_rectangles)

e800.fit(iterations=150)
e800.visualise()
e800.save_history_to_csv()
# Out:
# C:\Users\marys\PycharmProjects\EvolutionAlgorithms\cutting_stock_utils.py:62: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(c ** 2 - a ** 2)
# Generation 0 best score is 18900 for individual [ 1 12 13  5 12]
# Population average score is 12197.666666666666
# Generation 1 best score is 18900 for individual [ 1 12 13  5 12]
# Population average score is 13122.666666666666
# Generation 2 best score is 18200 for individual [ 3 11 15  5  8]
# Population average score is 13443.666666666666
# Generation 3 best score is 18120 for individual [ 0 14 10  8 12]
# Population average score is 13656.666666666666
# Generation 4 best score is 18120 for individual [ 0 14 10  8 12]
# Population average score is 13931.333333333334
# Generation 5 best score is 20000 for individual [ 4 14 12  5 13]
# Population average score is 14155.666666666666
# Generation 6 best score is 20000 for individual [ 4 14 12  5 13]
# Population average score is 14623.0
# ...

# %%
RECTANGLES = [copy.deepcopy(r800.rectangles[i]) for i, n in
              enumerate(e800.best_individual) for j in range(n)]
place_rectangles_in_circle(RECTANGLES, 800)
draw_rectangles(RECTANGLES, 800, e800.name)

# %% [markdown]
# # 2. Zbiór z promieniem 850

# %%
e850 = Evolution(crossover_ratio=0.7, mutation_ratio=0.2,
                     crossover=mean_crossover, mutation=int_mutation,
                     fitness_func=r850.fitness_function,
                     selection_func=elite_selection, population_size=60,
                     individual_size=r850.n_rectangles)

e850.fit(iterations=150)
e850.visualise()
e850.save_history_to_csv()
# Out:
# Generation 0 best score is 204010 for individual [ 3  5 13  9 12  9 14]
# Population average score is 132840.5
# Generation 1 best score is 207360 for individual [ 3  2 12 13  6  5 15]
# Population average score is 143823.0
# Generation 2 best score is 214460 for individual [ 3  6 10  0 15  8 16]
# Population average score is 151262.16666666666
# Generation 3 best score is 218950 for individual [ 0  7  6  1 12  9 17]
# Population average score is 159425.83333333334
# Generation 4 best score is 250150 for individual [ 5  7 17 13 13 11 17]
# Population average score is 168630.16666666666
# Generation 5 best score is 250150 for individual [ 5  7 17 13 13 11 17]
# Population average score is 174341.0
# Generation 6 best score is 250150 for individual [ 5  7 17 13 13 11 17]
# Population average score is 179839.33333333334
# Generation 7 best score is 250150 for individual [ 5  7 17 13 13 11 17]
# Population average score is 184797.16666666666
# ...

# %%
RECTANGLES = [copy.deepcopy(r850.rectangles[i]) for i, n in
              enumerate(e850.best_individual) for j in range(n)]
place_rectangles_in_circle(RECTANGLES, 850)
draw_rectangles(RECTANGLES, 850, e850.name)

# %% [markdown]
# # 3. Zbiór z promieniem 1000

# %%
e1000 = Evolution(crossover_ratio=0.7, mutation_ratio=0.2,
                     crossover=mean_crossover, mutation=int_mutation,
                     fitness_func=r1000.fitness_function,
                     selection_func=elite_selection, population_size=60,
                     individual_size=r1000.n_rectangles)

e1000.fit(iterations=150)
e1000.visualise()
e1000.save_history_to_csv()
# Out:
# Generation 0 best score is 13320 for individual [10 14 14  3]
# Population average score is 8492.333333333334
# Generation 1 best score is 13320 for individual [10 14 14  3]
# Population average score is 8942.333333333334
# Generation 2 best score is 13320 for individual [10 14 14  3]
# Population average score is 9369.333333333334
# Generation 3 best score is 13320 for individual [10 14 14  3]
# Population average score is 9717.666666666666
# Generation 4 best score is 13320 for individual [10 14 14  3]
# Population average score is 10006.0
# Generation 5 best score is 13320 for individual [10 14 14  3]
# Population average score is 10117.666666666666
# Generation 6 best score is 13400 for individual [11 11 15 10]
# Population average score is 10425.666666666666
# Generation 7 best score is 13400 for individual [11 11 15 10]
# Population average score is 10654.0
# Generation 8 best score is 13400 for individual [11 11 15 10]
# Population average score is 10848.333333333334
# ...

# %%
RECTANGLES = [copy.deepcopy(r1000.rectangles[i]) for i, n in
              enumerate(e1000.best_individual) for j in range(n)]
place_rectangles_in_circle(RECTANGLES, 1000)
draw_rectangles(RECTANGLES, 1000, e1000.name)

# %% [markdown]
# # 4. Zbiór z promieniem 1100

# %%
e1100 = Evolution(crossover_ratio=0.7, mutation_ratio=0.2,
                     crossover=mean_crossover, mutation=int_mutation,
                     fitness_func=r1100.fitness_function,
                     selection_func=elite_selection, population_size=60,
                     individual_size=r1100.n_rectangles)

e1100.fit(iterations=150)
e1100.visualise()
e1100.save_history_to_csv()
# Out:
# Generation 0 best score is 13080 for individual [12 10 14 12]
# Population average score is 7595.666666666667
# Generation 1 best score is 13080 for individual [12 10 14 12]
# Population average score is 8515.0
# Generation 2 best score is 13080 for individual [12 10 14 12]
# Population average score is 9003.0
# Generation 3 best score is 13080 for individual [12 10 14 12]
# Population average score is 9469.333333333334
# Generation 4 best score is 13080 for individual [12 10 14 12]
# Population average score is 9983.0
# Generation 5 best score is 13200 for individual [ 8 10 15 10]
# Population average score is 10303.0
# Generation 6 best score is 13200 for individual [ 8 10 15 10]
# Population average score is 10574.666666666666
# Generation 7 best score is 13200 for individual [ 8 10 15 10]
# Population average score is 10923.0
# Generation 8 best score is 15380 for individual [13 12 17  7]
# Population average score is 11233.666666666666
# ...

# %%
RECTANGLES = [copy.deepcopy(r1100.rectangles[i]) for i, n in
              enumerate(e1100.best_individual) for j in range(n)]
place_rectangles_in_circle(RECTANGLES, 1100)
draw_rectangles(RECTANGLES, 1100, e1100.name)

# %% [markdown]
# # 5. Zbiór z promieniem 1200

# %%
e1200 = Evolution(crossover_ratio=0.7, mutation_ratio=0.2,
                     crossover=mean_crossover, mutation=int_mutation,
                     fitness_func=r1200.fitness_function,
                     selection_func=elite_selection, population_size=60,
                     individual_size=r1200.n_rectangles)

e1200.fit(iterations=150)
e1200.visualise()
e1200.save_history_to_csv()
# Out:
# Generation 0 best score is 12900 for individual [10 13 14  0]
# Population average score is 8178.333333333333
# Generation 1 best score is 12900 for individual [10 13 14  0]
# Population average score is 8671.333333333334
# Generation 2 best score is 12620 for individual [12  7 16  3]
# Population average score is 9130.666666666666
# Generation 3 best score is 12620 for individual [12  7 16  3]
# Population average score is 9523.0
# Generation 4 best score is 13800 for individual [16 12 14  0]
# Population average score is 9988.0
# Generation 5 best score is 13800 for individual [16 12 14  0]
# Population average score is 10207.0
# Generation 6 best score is 13800 for individual [16 12 14  0]
# Population average score is 10402.0
# Generation 7 best score is 13800 for individual [16 12 14  0]
# Population average score is 10608.333333333334
# Generation 8 best score is 13280 for individual [12 11 15  2]
# Population average score is 10780.333333333334
# ...

# %%
RECTANGLES = [copy.deepcopy(r1200.rectangles[i]) for i, n in
              enumerate(e1200.best_individual) for j in range(n)]
place_rectangles_in_circle(RECTANGLES, 1200)
draw_rectangles(RECTANGLES, 1200, e1200.name)
